# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import xgboost as xgb
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.linear_model import RANSACRegressor
from sklearn.model_selection import GridSearchCV
import sklearn.metrics as metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin

# %%
pd.set_option('max_columns', None)

# %%
dados = pd.read_csv("dados_pre_processados.csv")
dados.drop("Unnamed: 0", axis = "columns", inplace=True)
#mask_tipo_traco = dados["TipoTraco"] == 'N'
#dados = dados[mask_tipo_traco]
dados.head()
# Out:
#    CodigoNotaFiscal  CodigoCentroSaida  CodigoReceita  Volume TipoLancamento  \
# 0            346641              80020         672051     8.0              B
# 1            346661              80020         672051     8.0              B
# 2            346695              80020         672051     7.0              B
# 3            347367              80020         672051     8.0              B
# 4            347388              80020         672051     6.0              B
#
#      DataEmissaoNotaFiscal  CodigoCliente  CodigoMotorista Status  \
# 0  2015-01-16 07:35:31.770        6248051            11080      N
# 1  2015-01-16 08:20:03.153        6248051            87079      N
# 2  2015-01-16 10:05:20.293        6248051            43080      N
# 3  2015-01-20 18:52:57.373       12343051            43080      N
# 4  2015-01-21 07:08:54.847        6248051            42080      N
#
#    QuantidadeAgua TempoPermanenciaObra  ConsumoTotal  Idade TipoTraco  \
# 0          1456.0             02:41:00        2720.0     28         N
# 1          1456.0             02:46:00        2720.0     28         N
# 2          1274.0             01:32:00        2380.0     28         N
# 3          1456.0             01:10:00        2720.0     28         N
# 4          1092.0             00:35:00        2040.0     28         N
#
#    CodigoAglomerante   FCK  Rompimento7Dias  Rompimento28Dias  ConsumoPorM3  \
# 0            12051.0  30.0            20.83             31.81         340.0
# 1            12051.0  30.0            19.62             31.21         340.0
# 2            12051.0  30.0            21.97             36.68         340.0
# 3            12051.0  30.0            28.21             40.21         340.0
# 4            12051.0  30.0            25.80             38.74         340.0
#
#    DesvioAplicado  ResultadoEsperado  ResultadoProjetado  \
# 0             3.5          39.430782           33.321754
# 1             3.5          39.430782           31.799067
# 2             3.5          39.430782           34.733698
# 3             3.5          39.430782           42.118539
# 4             3.5          39.430782           39.330637
#
#    PercentualCrescimentoReal  PercentualCrescimentoProjetado  \
# 0                  52.712434                       59.970014
# 1                  59.072375                       62.074756
# 2                  66.954939                       58.096029
# 3                  42.538107                       49.303577
# 4                  50.155039                       52.444329
#
#    RelacaoAguaCimento DataProjecao  QuantidadeAguaM3
# 0            0.535294   2015-01-16             182.0
# 1            0.535294   2015-01-16             182.0
# 2            0.535294   2015-01-16             182.0
# 3            0.535294   2015-01-23             182.0
# 4            0.535294   2015-01-23             182.0

# %%
dados_latex = dados[["CodigoReceita", "Volume", "TipoLancamento", "QuantidadeAgua", "TempoPermanenciaObra", "ConsumoTotal", "FCK", "Rompimento7Dias", "Rompimento28Dias", "DesvioAplicado", "ResultadoProjetado", "DataProjecao"]]
dados_latex.head()
# Out:
#    CodigoReceita  Volume TipoLancamento  QuantidadeAgua TempoPermanenciaObra  \
# 0         672051     8.0              B          1456.0             02:41:00
# 1         672051     8.0              B          1456.0             02:46:00
# 2         672051     7.0              B          1274.0             01:32:00
# 3         672051     8.0              B          1456.0             01:10:00
# 4         672051     6.0              B          1092.0             00:35:00
#
#    ConsumoTotal   FCK  Rompimento7Dias  Rompimento28Dias  DesvioAplicado  \
# 0        2720.0  30.0            20.83             31.81             3.5
# 1        2720.0  30.0            19.62             31.21             3.5
# 2        2380.0  30.0            21.97             36.68             3.5
# 3        2720.0  30.0            28.21             40.21             3.5
# 4        2040.0  30.0            25.80             38.74             3.5
#
#    ResultadoProjetado DataProjecao
# 0           33.321754   2015-01-16
# 1           31.799067   2015-01-16
# 2           34.733698   2015-01-16
# 3           42.118539   2015-01-23
# 4           39.330637   2015-01-23

# %%
dados_latex
# Out:
#        CodigoReceita  Volume TipoLancamento  QuantidadeAgua  \
# 0             672051     8.0              B          1456.0
# 1             672051     8.0              B          1456.0
# 2             672051     7.0              B          1274.0
# 3             672051     8.0              B          1456.0
# 4             672051     6.0              B          1092.0
# ...              ...     ...            ...             ...
# 64606       54240051     6.0              B          1224.0
# 64607       56263051     8.0              C          1576.0
# 64608       15579051     6.0              B          1188.0
# 64609       54135051     7.5              B          1530.0
# 64610       45199051     6.0              B          1158.0
#
#       TempoPermanenciaObra  ConsumoTotal   FCK  Rompimento7Dias  \
# 0                 02:41:00        2720.0  30.0            20.83
# 1                 02:46:00        2720.0  30.0            19.62
# 2                 01:32:00        2380.0  30.0            21.97
# 3                 01:10:00        2720.0  30.0            28.21
# 4                 00:35:00        2040.0  30.0            25.80
# ...                    ...           ...   ...              ...
# 64606             01:50:00        2226.0  30.0            24.58
# 64607             01:48:00        2512.0  35.0            37.01
# 64608             00:26:00        2160.0  25.0            19.35
# 64609             00:40:00        2550.0  30.0            31.79
# 64610             02:25:00        2316.0  35.0            28.72
#
#        Rompimento28Dias  DesvioAplicado  ResultadoProjetado DataProjecao
# 0                 31.81             3.5           33.321754   2015-01-16
# 1                 31.21             3.5           31.799067   2015-01-16
# 2                 36.68             3.5           34.733698   2015-01-16
# 3                 40.21             3.5           42.118539   2015-01-23
# 4                 38.74             3.5           39.330637   2015-01-23
# ...                 ...             ...                 ...          ...
# 64606             30.55             2.5           35.206583   2020-12-18
# 64607             45.66             3.5           48.747083   2020-12-18
# 64608             27.36             2.5           28.849696   2020-12-18
# 64609             43.19             4.5           41.676425   2020-12-18
# 64610             42.03             4.5           43.547415   2020-12-18
#
# [64611 rows x 12 columns]

# %%
mask_aglomerante = dados["CodigoAglomerante"] == 29051
dados_aglomerante = dados[mask_aglomerante]
dados_aglomerante.head()
# Out:
#      CodigoNotaFiscal  CodigoCentroSaida  CodigoReceita  Volume  \
# 936            345082              51020       23009051     8.0
# 937            345093              51020       23009051     8.0
# 938            345122              51020       23009051     7.0
# 939            367573              51020       23009051     8.0
# 940            367584              51020       23009051     8.0
#
#     TipoLancamento    DataEmissaoNotaFiscal  CodigoCliente  CodigoMotorista  \
# 936              B  2015-01-05 12:00:10.290       13204051           340051
# 937              B  2015-01-05 13:11:23.140       13204051            66079
# 938              B  2015-01-05 16:10:31.760       13204051           669051
# 939              B  2015-05-21 06:27:09.667       96259051           578051
# 940              B  2015-05-21 07:07:04.227       96259051           707051
#
#     Status  QuantidadeAgua TempoPermanenciaObra  ConsumoTotal  Idade  \
# 936      N          1368.0             00:45:00        2480.0     28
# 937      N          1344.0             01:10:00        2480.0     28
# 938      N          1176.0             00:30:00        2170.0     28
# 939      N          1360.0             01:42:00        2264.0     28
# 940      N          1360.0             01:02:00        2264.0     28
#
#     TipoTraco  CodigoAglomerante   FCK  Rompimento7Dias  Rompimento28Dias  \
# 936         N            29051.0  25.0            20.19             30.20
# 937         N            29051.0  25.0            20.34             29.47
# 938         N            29051.0  25.0            21.31             31.77
# 939         N            29051.0  25.0            16.01             25.82
# 940         N            29051.0  25.0            16.36             24.98
#
#      ConsumoPorM3  DesvioAplicado  ResultadoEsperado  ResultadoProjetado  \
# 936         310.0             6.0          43.601321           31.352014
# 937         310.0             6.0          44.456879           31.519600
# 938         310.0             6.0          44.456879           32.591885
# 939         283.0             3.5          39.508154           26.472941
# 940         283.0             3.5          39.508154           26.898126
#
#      PercentualCrescimentoReal  PercentualCrescimentoProjetado  \
# 936                  49.579000                       55.284865
# 937                  44.886922                       54.963620
# 938                  49.084937                       52.941742
# 939                  61.274204                       65.352533
# 940                  52.689487                       64.413973
#
#      RelacaoAguaCimento DataProjecao  QuantidadeAguaM3
# 936            0.551613   2015-01-09             171.0
# 937            0.541935   2015-01-09             168.0
# 938            0.541935   2015-01-09             168.0
# 939            0.600707   2015-05-22             170.0
# 940            0.600707   2015-05-22             170.0

# %%
len(dados_aglomerante)
# Out:
# 6388

# %%
dados_aglomerante["TipoTraco"].value_counts()
# Out:
# N    4327
# E    2061
# Name: TipoTraco, dtype: int64

# %%
dados_aglomerante["TipoLancamento"].value_counts()
# Out:
# B    5115
# C    1273
# Name: TipoLancamento, dtype: int64

# %%
len(dados_aglomerante)
# Out:
# 6388

# %%
dados_aglomerante["LogRompimento7Dias"] = np.log(dados_aglomerante["Rompimento7Dias"])
# Out:
# <ipython-input-592-336d0659c33b>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.box(dados_aglomerante, x="TipoLancamento", y="Rompimento28Dias", title='Tipo de Lançamento x Rompimento 28 Dias')
fig.show()
# Out:
# <div>                            <div id="d2fa954e-270b-4a97-99dc-562695aff752" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2fa954e-270b-4a97-99dc-562695aff752")) {                    Plotly.newPlot(                        "d2fa954e-270b-4a97-99dc-562695aff752",                        [{"alignmentgroup": "True", "hovertemplate": "TipoLancamento=%{x}<br>Rompimento28Dias=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "C", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B",  ...

# %%
fig = px.box(dados_aglomerante, x="TipoTraco", y="Rompimento28Dias", title='Tipo de Traço x Rompimento 28 Dias')
fig.show()
# Out:
# <div>                            <div id="492b4164-638b-4ca5-a43d-9a8dae7c2305" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("492b4164-638b-4ca5-a43d-9a8dae7c2305")) {                    Plotly.newPlot(                        "492b4164-638b-4ca5-a43d-9a8dae7c2305",                        [{"alignmentgroup": "True", "hovertemplate": "TipoTraco=%{x}<br>Rompimento28Dias=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "N", "
4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70d21277-d93f-49b7-8996-3efa4aae89c4")) {                    Plotly.newPlot(                        "70d21277-d93f-49b7-8996-3efa4aae89c4",                        [{"hovertemplate": "LogRompimento7Dias=%{x}<br>PercentualCrescimentoReal=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2.9699015135194693, 3.311637304949512, 3.139832617527748, 3.1232455938529506, 3.170105660498771, 3.286908235260028, 3.126321843257593, 3.2039652121324464, 2.785628335747585, 3.141130476243348, 3.110399348532117, 3.0525850851467737, 3.111735949310297, 2.758109400974947, 2.9512577834521614, 2.8570447537800976, 2.9231615807191558, 2.750470916986162, 2.727199019940971, 2.8390784635086144], "xaxis": "x", "y": [44.94612621857364, 46.591323368574564, 37.27272727272726, 51.80457746478875, 50.0209995800084, 34.23019431988041, 42.34313295304959, 29.35444579780755, 37.260950030845144, 23.17336792044964, 32.27819884083818, 35.71091166745393, 41.45146927871773, 44.51490171211161, 43.02143230527965, 39.80470993681793, 25.322580645161267, 38.78594249201277, 49.18247220405494, 32.86549707602337], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777 ...

# %%
dados_aglomerante["TipoTraco"].replace('N', 0, inplace = True)
dados_aglomerante["TipoTraco"].replace('E', 1, inplace = True)

dados_aglomerante["TipoLancamento"].replace('C', 0, inplace = True)
dados_aglomerante["TipoLancamento"].replace('B', 1, inplace = True)
# Out:
# /home/marina/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4563: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dados_aglomerante["DataProjecao"] = pd.to_datetime(dados_aglomerante["DataProjecao"])
dados_aglomerante.sort_values("DataProjecao", inplace=True)
# Out:
# <ipython-input-513-77c128e4e36d>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-513-77c128e4e36d>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def AchaCorrecaoDesvio(item):
    data_projecao_item = item["DataProjecao"]
    tipo_traco = item["TipoTraco"]
    desvio_projecao_atual = item["DesvioAplicado"]
    
    mask_data_projecao = dados_aglomerante["DataProjecao"] < data_projecao_item
    mask_tipo_traco = dados_aglomerante["TipoTraco"] == tipo_traco
    dados_projecao_anterior = dados_aglomerante[mask_data_projecao & mask_tipo_traco]
    
    if (len(dados_projecao_anterior) == 0):
        return 0
    
    desvio_projecao_anterior = dados_projecao_anterior.tail(1)["DesvioAplicado"].values[0]
    
    delta_desvio = desvio_projecao_atual - desvio_projecao_anterior
    
    return delta_desvio

# %%
dados_aglomerante["DeltaDesvio"] = dados_aglomerante.apply(AchaCorrecaoDesvio, axis = "columns")
#dados_aglomerante.tail().apply(AchaCorrecaoDesvio, axis = "columns")
# Out:
# <ipython-input-515-7b56fb428403>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#coluna_pred = "PercentualCrescimentoReal"
#coluna_comp = "PercentualCrescimentoProjetado"

coluna_pred = "Rompimento28Dias"
coluna_comp = "ResultadoProjetado"

#dados_aglomerante_modelo = dados_aglomerante[["LogRompimento7Dias", "FCK", "RelacaoAguaCimento", coluna_pred, coluna_comp, "Volume", "DataProjecao"]]
#dados_aglomerante_modelo["Rompimento28Predito"] = dados_aglomerante_modelo["ResultadoProjetado"]


dados_aglomerante_modelo = dados_aglomerante_modelo.fillna(0)

# %%
def RemoveOutliers(dados, coluna):
    q1 = dados[coluna].quantile(0.25)
    q3 = dados[coluna].quantile(0.75)
    iqr = q3 - q1
    
    maskOutlier = (dados[coluna] < (q1 - 1.5 * iqr)) | (dados[coluna] > (q3 + 1.5 * iqr))
    retorno = dados[maskOutlier == False]
    
    return retorno

def RemoveOutliersPorFCK(dados, coluna):
    fcks = dados["FCK"].sort_values().unique()
    
    retorno_final = pd.DataFrame(columns = dados.columns)
    
    for fck in fcks:
        dados_fck = dados[dados["FCK"] == fck]        
        retorno = RemoveOutliers(dados_fck, coluna)
        retorno_final = pd.concat([retorno_final, retorno], join = "inner")
        
    return retorno_final

#dados_aglomerante = RemoveOutliers(dados_aglomerante, "LogRompimento7Dias")
#dados_aglomerante = RemoveOutliers(dados_aglomerante, "PercentualCrescimentoReal")
#dados_aglomerante = RemoveOutliers(dados_aglomerante, "Rompimento28Dias")
#dados_aglomerante = RemoveOutliers(dados_aglomerante, "ConsumoPorM3")
#dados_aglomerante = RemoveOutliers(dados_aglomerante, "RelacaoAguaCimento")

# %%
class TypeSelector(BaseEstimator, TransformerMixin):
    def __init__(self, dtype):
        self.dtype = dtype
    def fit(self, X, y=None):
        return self
    def transform(self, X):        
        assert isinstance(X, pd.DataFrame)
        return X.select_dtypes(include=[self.dtype])
    
class Debug(BaseEstimator, TransformerMixin):
    def __init__(self, dtype):
        self.dtype = dtype
    def fit(self, X, y=None):
        return self
    def transform(self, X):        
        print(X)

#Crescimento -> GradientBoostingRegressor(random_state = 1, loss='lad', learning_rate = 0.23, min_samples_leaf = 5, min_samples_split = 5, n_estimators = 12))

parameters = {'loss':('ls', 'lad'),
              'learning_rate': np.arange(0.8, 1.2, 0.05),
              'min_samples_leaf': np.arange(3, 6, 1),
              'min_samples_split': np.arange(1, 5, 1),
              'n_estimators': np.arange(30, 80, 10)}

params = {'n_estimators': 200,
          'min_samples_leaf': 1,
          'min_samples_split': 4,
          'learning_rate': 0.05,
          'loss': 'ls'}

#best_params = {'learning_rate': 0.9000000000000001, 'loss': 'lad', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60}

modelo = Pipeline([
  ('features', FeatureUnion(
      transformer_list=[
          ('numericals', Pipeline([
              ('scaler', MinMaxScaler())
          ]))
      ]
  )),
  #('model', GridSearchCV(estimator = GradientBoostingRegressor(random_state = 1), 
  #                       param_grid = parameters,
  #                       scoring = 'f1',
  #                       cv=10))
  #('model', GradientBoostingRegressor(random_state = 1, loss='lad', learning_rate = 0.9, min_samples_leaf = 5, min_samples_split = 2, n_estimators = 60))
  #('model', RANSACRegressor(base_estimator=None, min_samples=1, residual_threshold=0.01, is_data_valid=None, is_model_valid=None, max_trials=100,stop_probability=0.99, loss='absolute_loss', random_state=1))
  #('model', DecisionTreeRegressor())
  ('model', xgb.XGBRegressor(n_estimators = 100, learning_rate = 0.15, reg_alpha = 0.6, random_state = 14, objective = 'reg:squarederror', max_depth = 2))
])

#{'ls', 'lad', 'huber', 'quantile'}

# %%
mask_fim_treino = dados_aglomerante["DataProjecao"] < dt.datetime(2019, 1, 1)
dados_treino = dados_aglomerante[mask_fim_treino]

mask_inicio_teste = dados_aglomerante["DataProjecao"] >= dt.datetime(2019, 1, 1)
dados_teste = dados_aglomerante[mask_inicio_teste]

# %%
print(len(x_test))
len(y_test)
# Out:
# 147
# 147

# %%
x_train = dados_treino[["LogRompimento7Dias", "FCK", "RelacaoAguaCimento"]] 
x_test = dados_teste[["LogRompimento7Dias", "FCK", "RelacaoAguaCimento"]]

y_train = dados_treino["Rompimento28Dias"].values.reshape(-1,1)
y_test = dados_teste["Rompimento28Dias"].values.reshape(-1,1)

# %%
modelo.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('numericals',
#                                                  Pipeline(steps=[('scaler',
#                                                                   MinMaxScaler())]))])),
#                 ('model',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, gamma=0, gpu_id=-1,
#                               importance_type='gain',
#                               interaction_constraints='', learning_rate=0.15,
#                               max_delta_step=0, max_depth=2, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#                               random_state=14, reg_alpha=0.6, reg_lambda=1,
#                               scale_pos_weight=1, subsample=1,
#                               tree_method='exact', validate_parameters=1,
#                               verbosity=None))])

# %%
y_pred = modelo.predict(x_test)

reg = modelo.named_steps['model']

mse = metrics.mean_squared_error(y_test, y_pred)
print(mse)
r2 = metrics.r2_score(y_test, y_pred)
r2
# Out:
# 10.638965028279406
# 0.7414827313909063

# %%
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)
for i, y_pred in enumerate(reg.staged_predict(x_test)):
    test_score[i] = reg.loss_(y_test, y_pred)

fig = plt.figure(figsize=(6, 6))
plt.subplot(1, 1, 1)
plt.title('Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, reg.train_score_, 'b-',
         label='Training Set Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='upper right')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-523-2de17ff7bc00> in <module>
#       1 test_score = np.zeros((params['n_estimators'],), dtype=np.float64)
# ----> 2 for i, y_pred in enumerate(reg.staged_predict(x_test)):
#       3     test_score[i] = reg.loss_(y_test, y_pred)
#       4
#       5 fig = plt.figure(figsize=(6, 6))
#
# AttributeError: 'XGBRegressor' object has no attribute 'staged_predict'

# %%
j = 0
melhor_modelo = []

for indice in dados_teste.index:
    dado = dados_teste.loc[indice]
    
    projecao_modelo_atual = dado["ResultadoEsperado"]
    resultado_real = dado["Rompimento28Dias"]
    predicao_modelo_novo = y_pred[j]
    
    erro_modelo_novo = abs(predicao_modelo_novo - resultado_real)
    erro_modelo_antigo = abs(projecao_modelo_atual - resultado_real)
    
    if (erro_modelo_novo < erro_modelo_antigo):
        melhor_modelo.append(1)
    else:
        melhor_modelo.append(0)
    
    j = j + 1
    
teste = pd.DataFrame(melhor_modelo, columns = ["MelhorModelo"])
print(len(teste))

print(len(teste[teste["MelhorModelo"] == 1]))
# Out:
# 147
# 130

# %%
130/147
# Out:
# 0.8843537414965986

# %%
def EncontraPercentualAcerto():
    mask_modelo_predito_melhor = df["ErroPredito"] < df["ErroProjetado"]
    quantidade_nf_modelo_eh_melhor = len(df[mask_modelo_predito_melhor])
    quantidade_total = len(df)

    return quantidade_nf_modelo_eh_melhor/quantidade_total

# %%
def CalculaErroProjetadoPorItem(item):
    diff = abs(item["Projetado"] - item["Real"])
    return diff * item["Volume"]

def CalculaErroPreditoPorItem(item):
    diff = abs(item["Predito"] - item["Real"])
    return diff * item["Volume"]

# %%
def SubstituirValoresPreditos(y_pred, dados_teste):
    j = 0
    for i in dados_teste.index:        
        dados_aglomerante_modelo.loc[i, "Rompimento28Predito"] = y_pred[j]
        j = j + 1
    
    return dados_aglomerante_modelo

# %%
datas_projecao = pd.Series(pd.to_datetime(dados_aglomerante["DataProjecao"]).unique())

data_projecao_atual = datas_projecao.iloc[7]
ultima_data_projecao = datas_projecao.iloc[len(datas_projecao) - 1]

lista_datas_projecao = []
quantidade_dados_treino = []
quantidade_dados_teste = []
percentuais_acerto = []
erros_projetado = []
erros_predito = []

while (data_projecao_atual < ultima_data_projecao):
    df = pd.DataFrame(columns = ["Real", "Projetado", "Predito", "Volume"])

    dados_treino = EncontrarDadosTreino(data_projecao_atual)
    dados_treino_sem_outliers = RemoveOutliers    #dados_sem_outliers = RemoveOutliersPorFCK(dados_sem_outliers, "Rompimento28Dias")
PorFCK(dados_treino, "LogRompimento7Dias")
    #dados_sem_outliers = RemoveOutliersPorFCK(dados_sem_outliers, "ConsumoPorM3")
    dados_treino_sem_outliers = RemoveOutliersPorFCK(dados_treino_sem_outliers, "RelacaoAguaCimento")
    
    tam_dados_treino = len(dados_treino_sem_outliers)
    
    #print(len(dados_treino))
    
    dados_teste = EncontrarDadosTeste(data_projecao_atual)
    tam_dados_teste = len(dados_teste)
    
    if (tam_dados_treino == 0):
        data_projecao_atual = data_projecao_atual + dt.timedelta(weeks = 1)
        continue
    elif (tam_dados_teste == 0):
        data_projecao_atual = data_projecao_atual + dt.timedelta(weeks = 1)
        continue
    
    lista_datas_projecao.append(data_projecao_atual)
    quantidade_dados_treino.append(tam_dados_treino)
    quantidade_dados_teste.append(tam_dados_teste)
    
    x_train = dados_treino_sem_outliers.drop([coluna_pred, "DataProjecao", "FCK"], axis = 1)
    y_train = dados_treino_sem_outliers[coluna_pred].values

    x_test = dados_teste.drop([coluna_pred, "DataProjecao", "FCK"], axis = 1)
    y_test = dados_teste[coluna_pred].values
    
    y_train = y_train.reshape(-1, 1)
    y_test = y_test.reshape(-1, 1)
    
    x_train_modelo = x_train.drop([coluna_comp, "Volume"], axis = 1)
    x_test_modelo = x_test.drop([coluna_comp, "Volume"], axis = 1)    
    
    modelo.fit(x_train_modelo, y_train)
    y_pred = modelo.predict(x_test_modelo)
    
    #dados_aglomerante_modelo = SubstituirValoresPreditos(y_pred, dados_teste)
    
    #mask_data_proj = dados_aglomerante_modelo["DataProjecao"] == data_projecao_atual
    #dados_aglomerante_modelo[mask_data_proj]["Rompimento28Predito"] = y_pred    
        
    df["Real"] = y_test.reshape(1, -1)[0]
    df["Projetado"] = x_test[coluna_comp].values
    df["Predito"] = y_pred
    df["Volume"] = x_test["Volume"].values
    
    df["ErroProjetado"] = df.apply(CalculaErroProjetadoPorItem, axis = "columns")
    df["ErroPredito"] = df.apply(CalculaErroPreditoPorItem, axis = "columns")
    
    erros_projetado.append(df["ErroProjetado"].sum())
    erros_predito.append(df["ErroPredito"].sum())
    
    perc_acerto = EncontraPercentualAcerto()    
    percentuais_acerto.append(perc_acerto)
    
    data_projecao_atual = data_projecao_atual + dt.timedelta(weeks = 1)
# Out:
#   File "<ipython-input-176-fc440cac5a43>", line 20
#     dados_treino_sem_outliers = RemoveOutliersPorFCK(dados_treino_sem_outliers, "RelacaoAguaCimento")
#     ^
# IndentationError: unexpected indent

# %%
params = {'n_estimators': 20,
          'min_samples_leaf': 1,
          'min_samples_split': 6,
          'learning_rate': 0.2,
          'loss': 'ls'}

#loss='ls', learning_rate = 0.2, min_samples_leaf = 1, min_samples_split = 6, n_estimators = 20

reg = modelo.named_steps['model']

x_test_01 = x_test_modelo["RelacaoAguaCimento"]

plt.scatter(x = x_test_01, y = y_test, color='black')
plt.plot(scaley = y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-177-867a5a0ea064> in <module>
#      11 x_test_01 = x_test_modelo["RelacaoAguaCimento"]
#      12
# ---> 13 plt.scatter(x = x_test_01, y = y_test, color='black')
#      14 plt.plot(scaley = y_pred, color='blue', linewidth=3)
#      15
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4439         y = np.ma.ravel(y)
#    4440         if x.size != y.size:
# -> 4441             raise ValueError("x and y must be the same size")
#    4442
#    4443         if s is None:
#
# ValueError: x and y must be the same size

# %%
dados_aglomerante_modelo

# %%
lista_datas_projecao_convertida = pd.to_datetime(lista_datas_projecao)

# %%
df_total = pd.DataFrame()

df_total["DataProjecao"] = lista_datas_projecao_convertida
df_total["QuantidadeDadosTreino"] = quantidade_dados_treino
df_total["QuantidadeDadosTeste"] = quantidade_dados_teste
df_total["PercentualAcerto"] = percentuais_acerto
df_total["ErroProjetado"] = erros_projetado
df_total["ErroPredito"] = erros_predito

df_total["ErroProjetadoNormalizado"] = df_total.apply(NormalizarErrosProjetado, axis = "columns")
df_total["ErroPreditoNormalizado"] = df_total.apply(NormalizarErrosPredito, axis = "columns")

df_total.sort_values("DataProjecao", ascending = True).head(5)
# Out:
#   DataProjecao  QuantidadeDadosTreino  QuantidadeDadosTeste  PercentualAcerto  \
# 0   2017-07-07                     10                     7          0.428571
# 1   2017-08-04                     10                     1          1.000000
# 2   2017-08-11                      8                     1          0.000000
# 3   2017-10-20                      2                    19          0.263158
# 4   2017-10-27                      2                     8          0.750000
#
#    ErroProjetado  ErroPredito  ErroProjetadoNormalizado  \
# 0     145.647931      212.440                  0.130442
# 1      17.960084       12.480                  0.012839
# 2      11.708642       14.495                  0.007081
# 3     222.600478      622.310                  0.201317
# 4     128.590378       63.120                  0.114732
#
#    ErroPreditoNormalizado
# 0                0.191959
# 1                0.007792
# 2                0.009648
# 3                0.569456
# 4                0.054432

# %%
def EncontrarMenorErro():
    min_erro_proj = df_total["ErroProjetado"].min()
    min_erro_pred = df_total["ErroPredito"].min()
    
    if (min_erro_proj < min_erro_pred):
        min_value = min_erro_proj
    else:
        min_value = min_erro_pred
    
    return min_value
   
def EncontrarMaiorErro():
    max_erro_proj = df_total["ErroProjetado"].max()
    max_erro_pred = df_total["ErroPredito"].max()

    if (max_erro_proj > max_erro_pred):
        max_value = max_erro_proj
    else:
        max_value = max_erro_pred
        
    return max_value
        
min_value = EncontrarMenorErro()
max_value = EncontrarMaiorErro()

diff = max_value - min_value

def NormalizarErrosProjetado(item):
    diff_sup = item["ErroProjetado"] - min_value
    return diff_sup/diff

def NormalizarErrosPredito(item):
    diff_sup = item["ErroPredito"] - min_value
    return diff_sup/diff

# %%
#df_total = df_total[df_total["DataProjecao"] >= dt.datetime(2018,1,1)]

soma_erro_proj = df_total["ErroProjetadoNormalizado"].sum()
soma_erro_pred = df_total["ErroPreditoNormalizado"].sum()

perc_erro_normalizado = soma_erro_pred * 100 / soma_erro_proj

print("Soma Erro Projetado", df_total["ErroProjetadoNormalizado"].sum())
print("Soma Erro Predito", df_total["ErroPreditoNormalizado"].sum())

print("Percentual Erro Predito", perc_erro_normalizado)

mask_perc_acerto_maior_50 = df_total["PercentualAcerto"] > 0.5
quantidade_acertos = len(df_total[mask_perc_acerto_maior_50]["PercentualAcerto"])
quantidade_total = len(df_total)

perc_acerto_geral = quantidade_acertos/quantidade_total

print("Percentual Acerto Total:", perc_acerto_geral)

mask_perc_diff_zero = df_total["PercentualAcerto"] > 0
mask_perc_diff_um = df_total["PercentualAcerto"] < 1

df_total = df_total.sort_values("PercentualAcerto")
df_total_sem_zero_e_um = df_total[mask_perc_diff_zero & mask_perc_diff_um]

print("Menor Percentual Acerto:")
print(df_total_sem_zero_e_um["PercentualAcerto"].head(1))

print("Maior Percentual Acerto:")
print(df_total_sem_zero_e_um["PercentualAcerto"].tail(1))
# Out:
# Soma Erro Projetado 4.8804892404427935
# Soma Erro Predito 11.95598454531639
# Percentual Erro Predito 244.97512352330594
# Percentual Acerto Total: 0.16666666666666666
# Menor Percentual Acerto:
# 5    0.083333
# Name: PercentualAcerto, dtype: float64
# Maior Percentual Acerto:
# 4    0.75
# Name: PercentualAcerto, dtype: float64
# <ipython-input-180-9789e6686c70>:25: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
df_total.head(30)
#Semanas 8 a 4
# Out:
#    DataProjecao  QuantidadeDadosTreino  QuantidadeDadosTeste  \
# 11   2018-03-09                      8                     5
# 21   2018-10-19                     19                     9
# 25   2018-11-16                     34                     4
# 17   2018-09-07                     18                     1
# 33   2019-01-11                     96                     6
# 15   2018-08-24                      9                     5
# 14   2018-08-10                      8                     8
# 13   2018-08-03                      6                     3
# 26   2018-11-23                     49                     3
# 22   2018-10-26                     21                    13
# 35   2019-01-25                     86                    10
# 9    2018-01-12                     51                     4
# 8    2017-12-15                     51                     2
# 37   2019-02-08                     87                     1
# 6    2017-11-17                     19                     1
# 27   2018-11-30                     44                     9
# 2    2017-08-11                      8                     1
# 10   2018-01-26                     26                     2
# 5    2017-11-03                      1                    12
# 36   2019-02-01                     93                    12
# 24   2018-11-09                     25                    10
# 38   2019-03-01                    108                    15
# 32   2019-01-04                     78                     7
# 29   2018-12-14                     53                    28
# 16   2018-08-31                     11                     5
# 19   2018-10-05                     21                     9
# 3    2017-10-20                      2                    19
# 28   2018-12-07                     51                    22
# 34   2019-01-18                     98                    10
# 12   2018-03-16                      5                     3
#
#     PercentualAcerto  ErroProjetado  ErroPredito  ErroProjetadoNormalizado  \
# 11          0.000000      39.643742      494.960                  0.032810
# 21          0.000000     144.252117      661.440                  0.129156
# 25          0.000000      29.139717      302.320                  0.023136
# 17          0.000000      29.126726       77.760                  0.023124
# 33          0.000000     108.372150      465.260                  0.096110
# 15          0.000000      59.382521      195.080                  0.050990
# 14          0.000000      60.349088      242.820                  0.051880
# 13          0.000000      27.566031      230.320                  0.021686
# 26          0.000000      70.411716      218.620                  0.061148
# 22          0.000000     208.967585      907.365                  0.188760
# 35          0.000000     168.285572      572.550                  0.151292
# 9           0.000000      91.087745      195.760                  0.080191
# 8           0.000000      44.540748       87.440                  0.037320
# 37          0.000000      33.937202       49.760                  0.027554
# 6           0.000000      36.523580       50.160                  0.029936
# 27          0.000000     112.507883     1008.940                  0.099919
# 2           0.000000      11.708642       14.495                  0.007081
# 10          0.000000       9.591244       30.360                  0.005131
# 5           0.083333     215.623217      432.040                  0.194890
# 36          0.083333     606.249087      854.820                  0.554664
# 24          0.100000      87.098369      228.680                  0.076517
# 38          0.133333     158.138175      558.550                  0.141946
# 32          0.142857      57.555646      191.430                  0.049307
# 29          0.178571     423.761880     1089.775                  0.386590
# 16          0.200000      79.129484      191.280                  0.069177
# 19          0.222222     235.061369      486.610                  0.212793
# 3           0.263158     222.600478      622.310                  0.201317
# 28          0.272727     310.184739      432.680                  0.281983
# 34          0.300000     155.943621      329.565                  0.139924
# 12          0.333333      71.758995      107.455                  0.062389
#
#     ErroPreditoNormalizado
# 11                0.452165
# 21                0.605496
# 25                0.274740
# 17                0.067916
# 33                0.424810
# 15                0.175970
# 14                0.219939
# 13                0.208426
# 26                0.197650
# 22                0.831997
# 35                0.523626
# 9                 0.176596
# 8                 0.076831
# 37                0.042127
# 6                 0.042496
# 27                0.925550
# 2                 0.009648
# 10                0.024260
# 5                 0.394214
# 36                0.783602
# 24                0.206916
# 38                0.510732
# 32                0.172608
# 29                1.000000
# 16                0.172470
# 19                0.444474
# 3                 0.569456
# 28                0.394804
# 34                0.299833
# 12                0.095266
